# %% [markdown]
# # Task 15:
# A few quick plots - Due at the end of class today, just to reinforce something I said during the last class but which you will need in a future class
# Please plot the following distributions together:
# A Normal distribution with mean=0 and variance=1
#
# A Normal distribution with mean=0 and variance=10
#
# A Normal distribution with mean=0 and variance=100
#
# A Normal distribution with mean=0 and variance=1000
#
# A Uniform distribution between 0 and 1000
#
# Put them all on the same graph with a title and a legend showing the color corresponding to each distribution
#
#
# Remember: uniform distributions are defined by a min and max value, all including those having the same probability

# %%
#example from the net

from numpy import * # I don't think this is typically how we handle numpy
import math
import matplotlib.pyplot as plt

t = linspace(0, 2*math.pi, 400)
a = sin(t)
b = cos(t)
c = a + b

plt.plot(t, a, 'r') # plotting t, a separately 
plt.plot(t, b, 'b') # plotting t, b separately 
plt.plot(t, c, 'g') # plotting t, c separately 
plt.show()

# %%
#another way of doing this same example

from numpy import *
import math
import matplotlib.pyplot as plt

t = linspace(0,2*math.pi,400)
a = sin(t)
b = cos(t)
c = a + b

plt.plot(t, a, t, b, t, c) #and you can change the color by adding a 'r', 'b', 'g' after each y parameter
plt.show()

# %%
# now adjusting to the distributions that we want
# Question: Why don't they use fig, ax here?

from numpy import *
import math
import matplotlib.pyplot as plt

t = linspace(0,2*math.pi,400)
a = sin(t)
b = cos(t)
c = a + b

plt.plot(t, a, t, b, t, c) #and you can change the color by adding a 'r', 'b', 'g' after each y parameter
plt.show()

# %% [markdown]
# ## Final implementation

# %%
# combining both things from the net

#imports
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm
from scipy.stats import uniform
import math

#setting y
n1 = norm.pdf(x, 0, 1)
n2 = norm.pdf(x, 0, 10)
n3 = norm.pdf(x, 0, 100)
u1 = uniform.pdf(x, loc = -100, scale = 200)

#setting x - Graphing for the largest variance
x = np.linspace(0 - 3*100, 0 + 3*100, 100)

plt.plot(x, n1, 'r', x, n2, 'b', x, n3,'g', x, u1, 'y') #and you can change the color by adding a 'r', 'b', 'g' after each y parameter
plt.show()
